# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html

# %%
import pandas as pd

# %%
df=pd.read_excel("pyladies.xlsx")
df
# Out:
#                   Informações da Clínica de Nutrição  Unnamed: 1  \
# 0                                   obs: alguma coisa        NaN
# 1                                                nome  documento
# 2                                               MARIA    8653287
# 3                                               Celso    2058021
# 4                                             Zuleide    6600351
# 5                                                BETO    7735611
# 6                                             Cecília    5842713
# 7                                        Ana Cristina    3504191
# 8                                              aurora    8894948
# 9                                                 NaN    3338125
# 10                                           Catarina     555784
# 11                                             Ângelo    8901510
# 12                                            Vitória   65137823
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Informações da Clínica de Nutrição   19 non-null     object
#  1   Unnamed: 1                           18 non-null     object
#  2   Unnamed: 2                           18 non-null     object
#  3   Unnamed: 3                           18 non-null     object
#  4   Unnamed: 4                           18 non-null     object
#  5   Unnamed: 5                           18 non-null     object
#  6   Unnamed: 6                           18 non-null     object
#  7   Unnamed: 7                           18 non-null     object
#  8   Unnamed: 8                           18 non-null     object
#  9   Unnamed: 9                           16 non-null     float64
#  10  Unnamed: 10                          0 non-null      float64
# ...

# %% [markdown]
# EXCLUIR LINHAS FORA DA TABELA

# %%
df=pd.read_excel("pyladies.xlsx",
                 skiprows = 2,
                skipfooter = 2)
df
# Out:
#             nome documento                           sexo data atualização  \
# 0          MARIA   8653287                       Feminino       2022-08-10
# 1          Celso   2058021                 Masculino            2022-09-22
# 2        Zuleide   6600351                       Feminino       2022-09-30
# 3           BETO   7735611                      Masculino       2022-06-05
# 4        Cecília   5842713                 Feminino             2022-02-02
# 5   Ana Cristina   3504191                       Feminino       2022-07-16
# 6         aurora   8894948                       Feminino       2021-11-24
# 7            NaN   3338125                   Masculino          2021-12-30
# 8       Catarina    555784                       Feminino       2022-10-01
# 9         Ângelo   8901510                      Masculino       2022-05-04
# 10       Vitória  65137823                       Feminino       2021-10-26
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nome              16 non-null     object
#  1   documento         17 non-null     object
#  2   sexo              17 non-null     object
#  3   data atualização  17 non-null     datetime64[ns]
#  4   altura            17 non-null     float64
#  5   peso              17 non-null     object
#  6   idade             17 non-null     object
#  7   meses tratamento  17 non-null     int64
#  8   nutricionista     17 non-null     object
#  9   Unnamed: 9        16 non-null     float64
#  10  Unnamed: 10       0 non-null      float64
#  11  Unnamed: 11       0 non-null      float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(6)
# memory usage: 1.7+ KB

# %%
df.columns
# Out:
# Index(['nome', 'documento', 'sexo', 'data atualização', 'altura', 'peso',
#        'idade', 'meses tratamento', 'nutricionista', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %% [markdown]
# EXCLUIR COLUNAS FORA DA TABELA

# %%
df = pd.read_excel("pyladies.xlsx",
                 skiprows = 2, 
                 skipfooter = 2,
                 usecols = ['nome', 'documento', 'sexo', 'data atualização', 'altura', 'peso',
                'idade', 'meses tratamento', 'nutricionista'],
                 na_values = "-")
df
# Out:
#             nome documento                           sexo data atualização  \
# 0          MARIA   8653287                       Feminino       2022-08-10
# 1          Celso   2058021                 Masculino            2022-09-22
# 2        Zuleide   6600351                       Feminino       2022-09-30
# 3           BETO   7735611                      Masculino       2022-06-05
# 4        Cecília   5842713                 Feminino             2022-02-02
# 5   Ana Cristina   3504191                       Feminino       2022-07-16
# 6         aurora   8894948                       Feminino       2021-11-24
# 7            NaN   3338125                   Masculino          2021-12-30
# 8       Catarina    555784                       Feminino       2022-10-01
# 9         Ângelo   8901510                      Masculino       2022-05-04
# 10       Vitória  65137823                       Feminino       2021-10-26
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nome              16 non-null     object
#  1   documento         17 non-null     object
#  2   sexo              17 non-null     object
#  3   data atualização  17 non-null     datetime64[ns]
#  4   altura            17 non-null     float64
#  5   peso              17 non-null     object
#  6   idade             16 non-null     float64
#  7   meses tratamento  17 non-null     int64
#  8   nutricionista     17 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 1.3+ KB

# %% [markdown]
# O READ_EXCEL NÃO TEM O PARÂMETRO skipinitialspace

# %%
df['sexo'].unique()
# Out:
# array(['                  Feminino', '   Masculino     ', 'Feminino',
#        'Masculino', 'Feminino      ', 'Masculino   ',
#        '         Masculino', '                     Feminino'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nome              16 non-null     object
#  1   documento         17 non-null     object
#  2   sexo              17 non-null     object
#  3   data atualização  17 non-null     datetime64[ns]
#  4   altura            17 non-null     float64
#  5   peso              17 non-null     object
#  6   idade             16 non-null     float64
#  7   meses tratamento  17 non-null     int64
#  8   nutricionista     17 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 1.3+ KB

# %% [markdown]
# ATENÇÃO: O READ_EXCEL NÃO AVISA QUANDO HÁ COLUNAS COM MIXED TYPES!

# %%
df["peso"].unique()
# Out:
# array([55.5, 74.3, 63, 102, 79.4, 78.6, 65, 83.6, 78.4, 110.5,
#        '          ', 85, 115, 50, 106, 126], dtype=object)

# %%
df[df['peso'] == 55.5]
# Out:
#     nome documento                        sexo data atualização  altura  peso  \
# 0  MARIA   8653287                    Feminino       2022-08-10    1.54  55.5
#
#    idade  meses tratamento nutricionista
# 0   50.0                 2         Maria

# %%
df['documento'].unique()
# Out:
# array([8653287, 2058021, 6600351, 7735611, 5842713, 3504191, 8894948,
#        3338125, 555784, 8901510, 65137823, 5015191, 5013874, 1132138,
#        '35309A', 15616516], dtype=object)

# %% [markdown]
# DEFINIR TIPO DE COLUNAS MIXED TYPES PARA NÃO FAZER BOBAGEM NA ANÁLISE

# %%
df = pd.read_excel("pyladies.xlsx",
                 skiprows = 2, 
                 skipfooter = 2,
                 usecols = ['nome', 'documento', 'sexo', 'data atualização', 'altura', 'peso',
                'idade', 'meses tratamento', 'nutricionista'],
                 na_values = "-",
                 dtype = {'documento':str, 'peso':str})
df
# Out:
#             nome documento                           sexo data atualização  \
# 0          MARIA   8653287                       Feminino       2022-08-10
# 1          Celso   2058021                 Masculino            2022-09-22
# 2        Zuleide   6600351                       Feminino       2022-09-30
# 3           BETO   7735611                      Masculino       2022-06-05
# 4        Cecília   5842713                 Feminino             2022-02-02
# 5   Ana Cristina   3504191                       Feminino       2022-07-16
# 6         aurora   8894948                       Feminino       2021-11-24
# 7            NaN   3338125                   Masculino          2021-12-30
# 8       Catarina    555784                       Feminino       2022-10-01
# 9         Ângelo   8901510                      Masculino       2022-05-04
# 10       Vitória  65137823                       Feminino       2021-10-26
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nome              16 non-null     object
#  1   documento         17 non-null     object
#  2   sexo              17 non-null     object
#  3   data atualização  17 non-null     datetime64[ns]
#  4   altura            17 non-null     float64
#  5   peso              17 non-null     object
#  6   idade             16 non-null     float64
#  7   meses tratamento  17 non-null     int64
#  8   nutricionista     17 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 1.3+ KB

# %%
df['peso'].unique()
# Out:
# array(['55.5', '74.3', '63', '102', '79.4', '78.6', '65', '83.6', '78.4',
#        '110.5', '          ', '85', '115', '50', '106', '126'],
#       dtype=object)

# %%
df['documento'].unique()
# Out:
# array(['8653287', '2058021', '6600351', '7735611', '5842713', '3504191',
#        '8894948', '3338125', '555784', '8901510', '65137823', '5015191',
#        '5013874', '1132138', '35309A', '15616516'], dtype=object)

# %% [markdown]
# COMO ESCOLHER A PLANILHA QUE QUERO IMPORTAR DO ARQUIVO EXCEL

# %%
df = pd.read_excel("pyladies.xlsx",
                 sheet_name="pyladies",
                 skiprows = 2, 
                 skipfooter = 2,
                 usecols = ['nome', 'documento', 'sexo', 'data atualização', 'altura', 'peso',
                'idade', 'meses tratamento', 'nutricionista'],
                 na_values = "-",
                 dtype = {'documento':str, 'peso':str})
df
# Out:
#             nome documento                           sexo data atualização  \
# 0          MARIA   8653287                       Feminino       2022-08-10
# 1          Celso   2058021                 Masculino            2022-09-22
# 2        Zuleide   6600351                       Feminino       2022-09-30
# 3           BETO   7735611                      Masculino       2022-06-05
# 4        Cecília   5842713                 Feminino             2022-02-02
# 5   Ana Cristina   3504191                       Feminino       2022-07-16
# 6         aurora   8894948                       Feminino       2021-11-24
# 7            NaN   3338125                   Masculino          2021-12-30
# 8       Catarina    555784                       Feminino       2022-10-01
# 9         Ângelo   8901510                      Masculino       2022-05-04
# 10       Vitória  65137823                       Feminino       2021-10-26
# ...

# %%
df = pd.read_excel("pyladies.xlsx",
                  sheet_name = 1)
df
# Out:
#   Unnamed: 0   Unnamed: 1    Unnamed: 2
# 0        mês  faturamento  atendimentos
# 1    janeiro      2.200,5             5
# 2  fevereiro      4.300,5            10
# 3      março      2.400,5             7
# 4      abril      2.500,5             6
# 5       maio      2.600,5             4
# 6      junho      6.700,5            14
# 7      julho     12.800,5            20
# 8     agosto     22.900,5            22
# 9   setembro     17.000,5            17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     object
#  1   Unnamed: 1  10 non-null     object
#  2   Unnamed: 2  10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes

# %%
df = pd.read_excel("pyladies.xlsx",
                  sheet_name = 1,
                  skiprows = 1)
df
# Out:
#          mês faturamento  atendimentos
# 0    janeiro     2.200,5             5
# 1  fevereiro     4.300,5            10
# 2      março     2.400,5             7
# 3      abril     2.500,5             6
# 4       maio     2.600,5             4
# 5      junho     6.700,5            14
# 6      julho    12.800,5            20
# 7     agosto    22.900,5            22
# 8   setembro    17.000,5            17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mês           9 non-null      object
#  1   faturamento   9 non-null      object
#  2   atendimentos  9 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 344.0+ bytes

# %%
df = pd.read_excel("pyladies.xlsx",
                  sheet_name = 1,
                  skiprows = 1,
                  decimal = ",",
                  thousands= ".")
df
# Out:
#          mês  faturamento  atendimentos
# 0    janeiro       2200.5             5
# 1  fevereiro       4300.5            10
# 2      março       2400.5             7
# 3      abril       2500.5             6
# 4       maio       2600.5             4
# 5      junho       6700.5            14
# 6      julho      12800.5            20
# 7     agosto      22900.5            22
# 8   setembro      17000.5            17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mês           9 non-null      object
#  1   faturamento   9 non-null      float64
#  2   atendimentos  9 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 344.0+ bytes

# %% [markdown]
# IMPORTAR DIVERSAS PLANILHAS DE UM MESMO EXCEL

# %%
df = pd.read_excel("pyladies.xlsx",
                  sheet_name = [0,1])
df
# Out:
# {0:                   Informações da Clínica de Nutrição  Unnamed: 1  \
#  0                                   obs: alguma coisa        NaN
#  1                                                nome  documento
#  2                                               MARIA    8653287
#  3                                               Celso    2058021
#  4                                             Zuleide    6600351
#  5                                                BETO    7735611
#  6                                             Cecília    5842713
#  7                                        Ana Cristina    3504191
#  8                                              aurora    8894948
#  9                                                 NaN    3338125
#  10                                           Catarina     555784
#  11                                             Ângelo    8901510
#  12                                            Vitória   65137823
# ...

# %%
type(df)
# Out:
# dict

# %%
df[0]
# Out:
#                   Informações da Clínica de Nutrição  Unnamed: 1  \
# 0                                   obs: alguma coisa        NaN
# 1                                                nome  documento
# 2                                               MARIA    8653287
# 3                                               Celso    2058021
# 4                                             Zuleide    6600351
# 5                                                BETO    7735611
# 6                                             Cecília    5842713
# 7                                        Ana Cristina    3504191
# 8                                              aurora    8894948
# 9                                                 NaN    3338125
# 10                                           Catarina     555784
# 11                                             Ângelo    8901510
# 12                                            Vitória   65137823
# ...

# %%
df[1]
# Out:
#   Unnamed: 0   Unnamed: 1    Unnamed: 2
# 0        mês  faturamento  atendimentos
# 1    janeiro      2.200,5             5
# 2  fevereiro      4.300,5            10
# 3      março      2.400,5             7
# 4      abril      2.500,5             6
# 5       maio      2.600,5             4
# 6      junho      6.700,5            14
# 7      julho     12.800,5            20
# 8     agosto     22.900,5            22
# 9   setembro     17.000,5            17

# %%
df = pd.read_excel("pyladies.xlsx",
                  sheet_name = None)
df
# Out:
# {'pyladies':                   Informações da Clínica de Nutrição  Unnamed: 1  \
#  0                                   obs: alguma coisa        NaN
#  1                                                nome  documento
#  2                                               MARIA    8653287
#  3                                               Celso    2058021
#  4                                             Zuleide    6600351
#  5                                                BETO    7735611
#  6                                             Cecília    5842713
#  7                                        Ana Cristina    3504191
#  8                                              aurora    8894948
#  9                                                 NaN    3338125
#  10                                           Catarina     555784
#  11                                             Ângelo    8901510
#  12                                            Vitória   65137823
# ...

# %%
df["pyladies"]
# Out:
#                   Informações da Clínica de Nutrição  Unnamed: 1  \
# 0                                   obs: alguma coisa        NaN
# 1                                                nome  documento
# 2                                               MARIA    8653287
# 3                                               Celso    2058021
# 4                                             Zuleide    6600351
# 5                                                BETO    7735611
# 6                                             Cecília    5842713
# 7                                        Ana Cristina    3504191
# 8                                              aurora    8894948
# 9                                                 NaN    3338125
# 10                                           Catarina     555784
# 11                                             Ângelo    8901510
# 12                                            Vitória   65137823
# ...

# %%
df["faturamento"]
# Out:
#   Unnamed: 0   Unnamed: 1    Unnamed: 2
# 0        mês  faturamento  atendimentos
# 1    janeiro      2.200,5             5
# 2  fevereiro      4.300,5            10
# 3      março      2.400,5             7
# 4      abril      2.500,5             6
# 5       maio      2.600,5             4
# 6      junho      6.700,5            14
# 7      julho     12.800,5            20
# 8     agosto     22.900,5            22
# 9   setembro     17.000,5            17
